# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/UTF_Data4.csv', sep=';')
df
# Out:
#                   Company name     Org. no Last annual report Currency  \
# 0      Ekman Invest Holding AB  5567121602             201912      SEK
# 1         Axfood Snabbgross AB  5560003575             201912      SEK
# 2                 LWW Group AB  5565295333             201912      SEK
# 3      Atteviks Bil Aktiebolag  5562130400             201912      SEK
# 4          SINKABERG INVEST AS   988947857             201912      NOK
# ..                         ...         ...                ...      ...
# 903          G. TSCHERNING A/S    26378443             202004      DKK
# 904                 TL BYG A/S    74101119             201906      DKK
# 905                 ONEPARK AS   998638984             201912      NOK
# 906  SAIPEM DRILLING NORWAY AS   998277418             201912      EUR
# 907      NSB TRAFIKKSERVICE AS   983581048             201912      NOK
#
#     Num. of employees, stock company 2020 (pcs)  \
# 0                                             -
# ...
