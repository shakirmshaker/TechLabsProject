# %% [markdown]
# ## Import Data and Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Import data
path = "Data/UTF_Data4.csv"
df = pd.read_csv(path, sep=';')
df = df.replace("-",np.nan)
df = df.replace("0",np.nan)
df.head(3)
# Out:
#               Company name     Org. no Last annual report Currency  \
# 0  Ekman Invest Holding AB  5567121602             201912      SEK
# 1     Axfood Snabbgross AB  5560003575             201912      SEK
# 2             LWW Group AB  5565295333             201912      SEK
#
#   Num. of employees, stock company 2020 (pcs)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#   Num. of employees, stock company 2019 (pcs)  \
# 0                                         301
# 1                                         411
# 2                                         347
#
#   Num. of employees, stock company 2018 (pcs)  \
# 0                                         NaN
# 1                                         401
# 2                                         361
#
#   Num. of employees, stock company 2017 (pcs)  \
# 0                                         283
# 1                                         384
# 2                                         337
#
#   Num. of employees, stock company 2016 (pcs)  \
# 0                                         279
# 1                                         365
# 2                                         332
#
#   Num. of employees, stock company 2015 (pcs)  ... Debt/equity ratio 2019 (%)  \
# 0                                          43  ...                       6,72
# 1                                         335  ...                       8,44
# 2                                         340  ...                       1,91
#
#   Debt/equity ratio 2018 (%) Debt/equity ratio 2017 (%)  \
# 0                       6,91                       5,23
# 1                      12,06                       12,1
# 2                       1,77                       1,77
#
#   Debt/equity ratio 2016 (%) Debt/equity ratio 2015 (%)  \
# 0                       5,41                       5,15
# 1                      15,42                      15,66
# 2                        1,1                       0,87
#
#   Debt/equity ratio 2014 (%) Debt/equity ratio 2013 (%)  \
# 0                       7,64                       6,14
# 1                      11,61                      10,54
# 2                       1,12                       1,05
#
#   Debt/equity ratio 2012 (%) Debt/equity ratio 2011 (%)  \
# 0                       5,71                       5,97
# 1                      12,19                      13,16
# 2                       1,02                       0,29
#
#   Debt/equity ratio 2010 (%)
# 0                       4,94
# 1                      15,34
# 2                       0,33
#
# [3 rows x 81 columns]

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# ### Get overview

# %%
# Get overview
print("Shape of the dataset:", df.shape)

df.describe(include="all")
# Out:
# Shape of the dataset: (908, 81)
#                   Company name       Org. no Last annual report Currency  \
# count                      908  9.080000e+02                907      908
# unique                     908           NaN                 26        5
# top     Apple Retail Sweden AB           NaN             201912      SEK
# freq                         1           NaN                702      593
# mean                       NaN  3.710139e+09                NaN      NaN
# std                        NaN  2.552399e+09                NaN      NaN
# min                        NaN  1.008975e+07                NaN      NaN
# 25%                        NaN  7.489792e+07                NaN      NaN
# 50%                        NaN  5.562348e+09                NaN      NaN
# 75%                        NaN  5.566133e+09                NaN      NaN
# max                        NaN  5.591762e+09                NaN      NaN
#
#        Num. of employees, stock company 2020 (pcs)  \
# count                                            5
# unique                                           1
# top                                            200
# freq                                             5
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Num. of employees, stock company 2019 (pcs)  \
# count                                          826
# unique                                         234
# top                                            200
# freq                                           250
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Num. of employees, stock company 2018 (pcs)  \
# count                                          853
# unique                                         283
# top                                            200
# freq                                           243
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Num. of employees, stock company 2017 (pcs)  \
# count                                          853
# unique                                         313
# top                                            200
# freq                                           245
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Num. of employees, stock company 2016 (pcs)  \
# count                                          833
# unique                                         308
# top                                            200
# freq                                           243
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Num. of employees, stock company 2015 (pcs)  ...  \
# count                                          808  ...
# unique                                         314  ...
# top                                            200  ...
# freq                                           232  ...
# mean                                           NaN  ...
# std                                            NaN  ...
# min                                            NaN  ...
# 25%                                            NaN  ...
# 50%                                            NaN  ...
# 75%                                            NaN  ...
# max                                            NaN  ...
#
#        Debt/equity ratio 2019 (%) Debt/equity ratio 2018 (%)  \
# count                         587                        642
# unique                        401                        425
# top                          1,09                       0,89
# freq                            6                          6
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#        Debt/equity ratio 2017 (%) Debt/equity ratio 2016 (%)  \
# count                         628                        612
# unique                        423                        401
# top                           1,1                       1,85
# freq                            5                          6
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#        Debt/equity ratio 2015 (%) Debt/equity ratio 2014 (%)  \
# count                         605                        588
# unique                        387                        389
# top                          0,87                       1,07
# freq                            7                          6
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#        Debt/equity ratio 2013 (%) Debt/equity ratio 2012 (%)  \
# count                         568                        557
# unique                        381                        380
# top                          1,53                       1,13
# freq                            6                          5
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#        Debt/equity ratio 2011 (%) Debt/equity ratio 2010 (%)
# count                         496                        478
# unique                        362                        352
# top                           0,6                       1,91
# freq                            5                          5
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
# [11 rows x 81 columns]

# %% [markdown]
# ### Remove missing values
# 1. List/plot the number of missing values for each column
# 2. Remove columns with many missing values
# 3. Then remove all rows with missing values
#
# When done, use .describe() again and see the changes

# %%
def removeRareColumns(df, threshold=0.80):
    dfLength = len(df)
    for column in df:
        count = df[column].count()
        percent = count / dfLength

        if percent < threshold:
            print(column)
            df = df.drop(column, axis=1)
        else:
            pass
    return df

df = removeRareColumns(df)
# Out:
# Num. of employees, stock company 2020 (pcs)
# Num. of employees, stock company 2012 (pcs)
# Num. of employees, stock company 2011 (pcs)
# Num. of employees, stock company 2010 (pcs)
# EBITDA 2020 (k)
# EBITDA 2012 (k)
# EBITDA 2011 (k)
# EBITDA 2010 (k)
# Gross profit/loss 2020 (k)
# Gross profit/loss 2019 (k)
# Gross profit/loss 2018 (k)
# Gross profit/loss 2017 (k)
# Gross profit/loss 2016 (k)
# Gross profit/loss 2015 (k)
# Gross profit/loss 2014 (k)
# Gross profit/loss 2013 (k)
# Gross profit/loss 2012 (k)
# Gross profit/loss 2011 (k)
# Gross profit/loss 2010 (k)
# R & D costs 2020 (k)
# R & D costs 2019 (k)
# R & D costs 2018 (k)
# R & D costs 2017 (k)
# R & D costs 2016 (k)
# R & D costs 2015 (k)
# R & D costs 2014 (k)
# R & D costs 2013 (k)
# R & D costs 2012 (k)
# R & D costs 2011 (k)
# R & D costs 2010 (k)
# Total assets 2020 (k)
# Total assets 2012 (k)
# Total assets 2011 (k)
# Total assets 2010 (k)
# Quick ratio 2020 (%)
# Quick ratio 2012 (%)
# Quick ratio 2011 (%)
# Quick ratio 2010 (%)
# Debt/equity ratio 2020 (%)
# Debt/equity ratio 2019 (%)
# Debt/equity ratio 2018 (%)
# Debt/equity ratio 2017 (%)
# Debt/equity ratio 2016 (%)
# Debt/equity ratio 2015 (%)
# Debt/equity ratio 2014 (%)
# Debt/equity ratio 2013 (%)
# Debt/equity ratio 2012 (%)
# Debt/equity ratio 2011 (%)
# Debt/equity ratio 2010 (%)

# %%
df.dropna()
# Out:
#                            Company name     Org. no Last annual report  \
# 1                  Axfood Snabbgross AB  5560003575             201912
# 2                          LWW Group AB  5565295333             201912
# 3               Atteviks Bil Aktiebolag  5562130400             201912
# 5        GIPEJO Förvaltnings Aktiebolag  5563246312             201912
# 6    Bröderna Börjessons Bil Aktiebolag  5561762864             201912
# ..                                  ...         ...                ...
# 901                           EGONS A/S    33053835             201912
# 902                   DEICHMANN-SKO ApS    27278388             201912
# 903                   G. TSCHERNING A/S    26378443             202004
# 906           SAIPEM DRILLING NORWAY AS   998277418             201912
# 907               NSB TRAFIKKSERVICE AS   983581048             201912
#
#     Currency Num. of employees, stock company 2019 (pcs)  \
# 1        SEK                                         411
# 2        SEK                                         347
# 3        SEK                                         453
# 5        SEK                                         272
# 6        SEK                                         399
# ..       ...                                         ...
# 901      DKK                                         200
# 902      DKK                                         200
# 903      DKK                                         200
# 906      EUR                                         224
# 907      NOK                                         272
#
#     Num. of employees, stock company 2018 (pcs)  \
# 1                                           401
# 2                                           361
# 3                                           443
# 5                                           245
# 6                                           399
# ..                                          ...
# 901                                         200
# 902                                         200
# 903                                         200
# 906                                         190
# 907                                         263
#
#     Num. of employees, stock company 2017 (pcs)  \
# 1                                           384
# 2                                           337
# 3                                           434
# 5                                           203
# 6                                           275
# ..                                          ...
# 901                                         200
# 902                                         200
# 903                                         200
# 906                                         230
# 907                                         274
#
#     Num. of employees, stock company 2016 (pcs)  \
# 1                                           365
# 2                                           332
# 3                                           419
# 5                                           193
# 6                                           234
# ..                                          ...
# 901                                         200
# 902                                         200
# 903                                         200
# 906                                         223
# 907                                         277
#
#     Num. of employees, stock company 2015 (pcs)  \
# 1                                           335
# 2                                           340
# 3                                           407
# 5                                           172
# 6                                           230
# ..                                          ...
# 901                                         200
# 902                                         200
# 903                                         200
# 906                                         225
# 907                                         266
#
#     Num. of employees, stock company 2014 (pcs)  ... Total assets 2015 (k)  \
# 1                                           316  ...               331 720
# 2                                           346  ...               777 425
# 3                                           344  ...               894 424
# 5                                           154  ...               736 550
# 6                                           222  ...               749 059
# ..                                          ...  ...                   ...
# 901                                         100  ...                78 335
# 902                                         200  ...                78 128
# 903                                         200  ...               123 125
# 906                                         229  ...               814 708
# 907                                         261  ...                77 375
#
#     Total assets 2014 (k) Total assets 2013 (k) Quick ratio 2019 (%)  \
# 1                 288 487               236 497                 27,6
# 2                 868 339               816 246                   81
# 3                 723 909               606 718                124,5
# 5                 542 758               408 265                 40,9
# 6                 578 237               463 515                 73,5
# ..                    ...                   ...                  ...
# 901                64 346                75 321                 1,35
# 902                82 056                94 092                 4,48
# 903               124 368                96 692                 1,29
# 906               841 531             1 040 811                 0,11
# 907                63 016                68 453                 3,27
#
#     Quick ratio 2018 (%) Quick ratio 2017 (%) Quick ratio 2016 (%)  \
# 1                   34,7                 30,6                 42,9
# 2                   86,3                   88                  110
# 3                  134,9                 89,9                101,1
# 5                   41,5                 37,9                 42,8
# 6                   67,7                 71,2                 78,5
# ..                   ...                  ...                  ...
# 901                 1,26                 1,29                  1,2
# 902                 4,67                 2,64                 2,59
# 903                 1,23                 1,15                 1,17
# 906                  2,3                 9,83                 2,34
# 907                 3,28                 1,74                 1,84
#
#     Quick ratio 2015 (%) Quick ratio 2014 (%) Quick ratio 2013 (%)
# 1                   49,1                 51,4                 35,5
# 2                  121,8                104,4                 97,5
# 3                   77,3                   83                 87,8
# 5                   42,8                   50                 56,4
# 6                  110,8                 95,6                 87,4
# ..                   ...                  ...                  ...
# 901                 1,17                 0,84                 0,75
# 902                 2,87                 2,23                 1,85
# 903                  0,9                 0,99                 1,08
# 906                 1,23                 0,34                 0,33
# 907                 1,68                 1,36                 1,41
#
# [576 rows x 32 columns]

# %% [markdown]
# ### Remove outliers
# Use winzorization:
#
# df = winDf.clip(df.quantile(0.05), df.quantile(0.95), axis=1)

# %% [markdown]
# ### One-hot encode the columns with text or categorical values
# Probably not necessary for our case

# %% [markdown]
# ### If needed, calculate predictor column

# %% [markdown]
# ### Make some interesting plots (can be skipped)

# %% [markdown]
# # Modeling
